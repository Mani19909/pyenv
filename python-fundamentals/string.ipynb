# %%
single_line_str = "Double quoted"
single_line_str2 = 'single quoted'
print (single_line_str)
print (single_line_str2)

command_template = """
I will not be indented
    I will be indented
"""
print(command_template)
# Out:
# Double quoted
# single quoted
#
# I will not be indented
#     I will be indented

# %% [markdown]
# Strings
#
# String Manipulation
#
# 1. Strings are ordered, immutable sequences of chracters.
# 2. Use single or double quotes consistently; triple quotes for multi-line strings or docstrings.

# %% [markdown]
# Formate Output using f-string
#
# Tip: f-string (formatted string literal) is used to insert variables directly inside strings and format output easily.

# %%
math_division = 7/2
print(f"Result: {math_division}")

name = "mani"
inital = "routhu"
print(f"full name: {name} {inital}")
# Out:
# Result: 3.5
# full name: mani routhu

# %% [markdown]
# Common OPerations and Essential string methods
#
# 1. Concatenation (+): Joins strings.
# 2. Length (len()): Gets the number of characters.
# 3. Indexing ([]): Access a character by position (0-based).
# 4. Slicing ([:]): Extract substrings.
# 5. .lower() / .upper()
# 6. .strip() / .lstrip() / .rstrip()
# 7. .startswith() / .endswith()
# 8. .split() / .join()
# 9. .replace()

# %%
course_title = "       Python for DevOps     "
print(course_title)
print(f"Result of .strip(): {course_title.strip()}")
print(f"Result of .lstrip(): {course_title.lstrip()}")
print(f"Result of .rstrip(): {course_title.rstrip()}")
print(f"Result of .upper(): {course_title.upper()}")
print(f"Result of .lower(): {course_title.lower()}")

filename = "file.yaml"
print(filename.startswith("file"))
print(filename.endswith("yaml"))

path = "/usr/local/bin"
path_parts = path.split("/")
print(f"path parts: {path_parts}")
print(f"joined path paths: {"\\".join(path_parts)}")

print(path + "/python")
print(len(path))
print(path[3])
print(path[3:10])
print(path[:10])
print(path[3:])
# Out:
#        Python for DevOps
# Result of .strip(): Python for DevOps
# Result of .lstrip(): Python for DevOps
# Result of .rstrip():        Python for DevOps
# Result of .upper():        PYTHON FOR DEVOPS
# Result of .lower():        python for devops
# True
# True
# path parts: ['', 'usr', 'local', 'bin']
# joined path paths: \usr\local\bin
# /usr/local/bin/python
# 14
# r
# r/local
# /usr/local
# r/local/bin

# %% [markdown]
# String Immutability
#
# Strings are immutable, meaning you cannot change a string in place; operations that seem to modify a string actually create and return a new string object.

# %%
course_title = "       Python for DevOps     "
print(course_title)
print(f"Result of .strip(): {course_title.strip()}")
print(f"Result of .lstrip(): {course_title.lstrip()}")
print(f"Result of .rstrip(): {course_title.rstrip()}")
print(f"Result of .upper(): {course_title.upper()}")
print(f"Result of .lower(): {course_title.lower()}")
print(course_title)
# Out:
#        Python for DevOps
# Result of .strip(): Python for DevOps
# Result of .lstrip(): Python for DevOps
# Result of .rstrip():        Python for DevOps
# Result of .upper():        PYTHON FOR DEVOPS
# Result of .lower():        python for devops
#        Python for DevOps

# %% [markdown]
# Exercise: Calculate Disk Usage Percentage
#
# In this exercise you’ll combine basic arithmetic with f‑string formatting to report disk usage for a server.
#
# Objectives:
#
# 1. Given the variables below, compute the disk usage percentage.
# 2. Print the raw percentage value.
# 3. Build a human‑readable summary string:
#
#     i. Convert the server name to uppercase.
#
#     ii.Include the number of CPU cores and amount of RAM.
#
#     iii.Show the disk usage percentage rounded to one decimal place.
#
# 4. Print a summary containing the server name in uppercase, the number of CPU cores, the memory, and the disk usage).
# 5. Finally, use the .2% format specifier in an f‑string to display the usage with two decimal places and a percent sign.

# %%
server_name = "webserver-03"
cpu_cores = 4 
memory_gb = 8.0
disk_total_gb = 500
disk_used_gb = 350

disk_usage_percentage = disk_used_gb / disk_total_gb
print(disk_usage_percentage)

summary = f"server '{server_name.upper()}' ({cpu_cores} cores, {memory_gb}GB RAM) Disk usage: {disk_usage_percentage}"
print(summary)

summary_formatted = f"server '{server_name.upper()}' ({cpu_cores} cores, {memory_gb}GB RAM) Disk usage: {disk_usage_percentage: .2%}"
print(summary_formatted)
# Out:
# 0.7
# server 'WEBSERVER-03' (4 cores, 8.0GB RAM) Disk usage: 0.7
# server 'WEBSERVER-03' (4 cores, 8.0GB RAM) Disk usage:  70.00%
